# %% [markdown]
# <a href="https://colab.research.google.com/github/AroopGit/Compute_Tasks/blob/main/Task_2_Q2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data.csv")
df.head()
# Out:
#    Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0           0        0.0102         0.833       204600   0.434
# 1           1        0.1990         0.743       326933   0.359
# 2           2        0.0344         0.838       185707   0.412
# 3           3        0.6040         0.494       199413   0.338
# 4           4        0.1800         0.678       392893   0.561
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.021900    2    0.1650    -8.795     1       0.4310  150.062
# 1          0.006110    1    0.1370   -10.401     1       0.0794  160.083
# 2          0.000234    2    0.1590    -7.148     1       0.2890   75.044
# 3          0.510000    5    0.0922   -15.236     1       0.0261   86.468
# 4          0.512000    5    0.4390   -11.648     0       0.0694  174.004
#
#    time_signature  valence  target      song_title            artist
# 0             4.0    0.286       1        Mask Off            Future
# ...

# %%
df.tail(10)
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 2007        2007      0.002170         0.639       296276   0.978
# 2008        2008      0.054100         0.646       160408   0.714
# 2009        2009      0.004990         0.595       224000   0.837
# 2010        2010      0.002310         0.624       206013   0.971
# 2011        2011      0.000586         0.528       245053   0.879
# 2012        2012      0.001060         0.584       274404   0.932
# 2013        2013      0.087700         0.894       182182   0.892
# 2014        2014      0.008570         0.637       207200   0.935
# 2015        2015      0.001640         0.557       185600   0.992
# 2016        2016      0.002810         0.446       204520   0.915
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 2007          0.112000   11    0.0838    -2.376     1       0.0730  144.986
# 2008          0.000000    0    0.1340    -6.511     1       0.0378   97.957
# ...

# %%
df.shape
# Out:
# (2017, 17)

# %%
df.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0              0       0.01020         0.833       204600   0.434
# 1              1       0.19900         0.743       326933   0.359
# 2              2       0.03440         0.838       185707   0.412
# 3              3       0.60400         0.494       199413   0.338
# 4              4       0.18000         0.678       392893   0.561
# ...          ...           ...           ...          ...     ...
# 2012        2012       0.00106         0.584       274404   0.932
# 2013        2013       0.08770         0.894       182182   0.892
# 2014        2014       0.00857         0.637       207200   0.935
# 2015        2015       0.00164         0.557       185600   0.992
# 2016        2016       0.00281         0.446       204520   0.915
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence', 'target',
#        'song_title', 'artist'],
#       dtype='object')

# %%
df.nlargest(10,"energy")
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 1299        1299      0.002560         0.468       201783   0.998
# 1322        1322      0.000049         0.428       221776   0.997
# 1297        1297      0.000015         0.455       311217   0.994
# 1347        1347      0.000017         0.329       135653   0.993
# 1332        1332      0.000290         0.424       271560   0.992
# 1680        1680      0.000048         0.409       200677   0.992
# 2015        2015      0.001640         0.557       185600   0.992
# 1328        1328      0.000013         0.517       256920   0.991
# 1296        1296      0.000127         0.237       247533   0.990
# 1681        1681      0.000285         0.458       211430   0.990
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 1299          0.000000    9    0.2330    -0.994     0       0.1500  140.003
# 1322          0.955000    8    0.2530    -3.587     1       0.1850  149.998
# ...

# %% [markdown]
# These are the top 10 most energetic songs

# %%
df.sort_values("duration_ms",  ascending=False)
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 1535        1535       0.99200         0.447      1004627  0.1630
# 695          695       0.02960         0.907       849960  0.6430
# 819          819       0.00497         0.376       825027  0.8010
# 1603        1603       0.99100         0.295       784013  0.0918
# 1565        1565       0.91000         0.421       763467  0.0967
# ...          ...           ...           ...          ...     ...
# 936          936       0.18900         0.555        52006  0.7590
# 1583        1583       0.82600         0.876        51547  0.3010
# 1591        1591       0.74100         0.941        47547  0.2560
# 1436        1436       0.00101         0.466        16588  0.9430
# 1044        1044       0.73300         0.409        16042  0.6450
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 1535          0.776000    8    0.6540   -14.835     1       0.0707   74.933
# ...

# %% [markdown]
# These are some of the largest songs in the dataframe

# %%
df.sort_values('danceability')['song_title'].head(10)
# Out:
# 729                                            Bumpy Road
# 532                                       Wake Bake Skate
# 817     Mozart: Requiem in D Minor, K. 626: VIII. Lacr...
# 1600           Trio Sonata in G Major, Wq. 144: I. Adagio
# 1598    Piano Quartet in E flat, Op.47: 3. Andante can...
# 522                                                 Outro
# 1348                 Be My Valentine (feat. Dickie Allen)
# 1464                                           Right Here
# 1313                                      Senseless Order
# 1306                                                 Ruin
# Name: song_title, dtype: object

# %%
df.sort_values('danceability')[['song_title', 'artist']].head(10)
# Out:
#                                              song_title  \
# 729                                          Bumpy Road
# 532                                     Wake Bake Skate
# 817   Mozart: Requiem in D Minor, K. 626: VIII. Lacr...
# 1600         Trio Sonata in G Major, Wq. 144: I. Adagio
# 1598  Piano Quartet in E flat, Op.47: 3. Andante can...
# 522                                               Outro
# 1348               Be My Valentine (feat. Dickie Allen)
# 1464                                         Right Here
# 1313                                    Senseless Order
# 1306                                               Ruin
#
#                          artist
# 729            Destruction Unit
# 532                      FIDLAR
# 817        Nikolaus Harnoncourt
# 1600  Carl Philipp Emanuel Bach
# 1598            Robert Schumann
# 522                         M83
# 1348                     Brojob
# 1464              Keys N Krates
# 1313         Signs of the Swarm
# ...

# %%
df.sort_values('loudness')[['song_title', 'artist', 'loudness']].tail(10)
# Out:
#                        song_title                     artist  loudness
# 1307                   Fauxhammer               Black Tongue    -1.374
# 591             Higher - Extended      Just Blaze and Baauer    -1.367
# 1467                         Help                    Borgore    -1.258
# 629                      Pop That             French Montana    -1.188
# 205         Double Bubble Trouble                     M.I.A.    -1.157
# 1299                No Absolution          Thy Art Is Murder    -0.994
# 2010  Hey Baby - Steve Aoki Remix  Dimitri Vegas & Like Mike    -0.935
# 1443                     The Wall       Matrix & Futurebound    -0.787
# 636       The Lion - Original Mix             The Partysquad    -0.718
# 195                  GodLovesUgly                 Atmosphere    -0.307

# %%
df_filt = df[df['duration_ms'] < 200000]
df_filt.shape
# Out:
# (504, 17)

# %%
df_filt.sort_values('energy')[['song_title', 'artist', 'duration_ms','energy']].tail(10)
# Out:
#                             song_title             artist  duration_ms  energy
# 391                    Black And White     Parquet Courts       182987   0.975
# 2004  Phone Down - Dodge & Fuski Remix         Lost Kings       198400   0.975
# 1615                         Milky Way       Madison Mars       192000   0.975
# 1929               Every time we touch            Cascada       197124   0.976
# 1318                              Rope  Obscure of Acacia       192011   0.978
# 801                Drifting In And Out     Porcelain Raft       194400   0.979
# 1323                       Zerotonin 2            Darknet       197684   0.980
# 1468                        Waist Time              Diplo       198750   0.989
# 2015                     First Contact         Twin Moons       185600   0.992
# 1347                        Unanswered    Suicide Silence       135653   0.993

# %%
df_2=df[df['energy']>0.4]
df_2.shape
# Out:
# (1830, 17)

# %%
df_2['song_title'].head(10)
# Out:
# 0                                 Mask Off
# 2                             Xanny Family
# 4                           Parallel Lines
# 5                                 Sneakin’
# 6                              Childs Play
# 8                        I've Seen Footage
# 9                           Digital Animal
# 10    Subways - In Flagranti Extended Edit
# 11              Donme Dolap - Baris K Edit
# 12                                 Cemalim
# Name: song_title, dtype: object
